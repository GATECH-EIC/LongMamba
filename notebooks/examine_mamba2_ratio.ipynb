# %%
import torch
import matplotlib.pyplot as plt

# %%
# create 4 x7 subplots
fig, axs = plt.subplots(9, 9, figsize=(15, 15))

for i in range(48):
    decay = torch.load(f'/data/kxia2/mamba/artifacts/mamba2-1.3b-thepile_new00/tA_prod/tA_prod_layer_{i}.pt')
    ax = axs[i//9, i%9]
    ax.plot(torch.log(decay.sort()[0].cpu()))
